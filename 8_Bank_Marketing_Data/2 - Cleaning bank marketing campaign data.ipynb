# %%
# Start coding...
import pandas as pd
import numpy as np

# Read in csv
marketing = pd.read_csv("bank_marketing.csv")

# Split into the three tables
client = marketing[["client_id", "age", "job", "marital", 
                    "education", "credit_default", "mortgage"]]
campaign = marketing[["client_id", "number_contacts", "month", "day", 
               "contact_duration", "previous_campaign_contacts", "previous_outcome", "campaign_outcome"]]
economics = marketing[["client_id", "cons_price_idx", "euribor_three_months"]]

# %%
## Editing the client dataset
# Clean education column
client.loc[:,"education"] = client["education"].str.replace(".", "_")
client.loc[:,"education"] = client["education"].replace("unknown", np.nan)

# %%
# Clean job column
client.loc[:, "job"] = client["job"].str.replace(".", "_")

# Clean and convert client columns to bool data type
for col in ["credit_default", "mortgage"]:
  client.loc[:,col] = client[col].map({"yes": 1,
                                 "no": 0,
                                 "unknown": 0})
  client.loc[:,col] = client[col].astype(bool)
# Out:
# /var/folders/rk/vsbmyjqx09n87m8t22syxyvr0000gn/T/ipykernel_94644/1961928141.py:6: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[nan nan nan ... nan nan nan]' has dtype incompatible with bool, please explicitly cast to a compatible dtype first.
#   client.loc[:,col] = client[col].map({"yes": 1,
# /var/folders/rk/vsbmyjqx09n87m8t22syxyvr0000gn/T/ipykernel_94644/1961928141.py:9: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[ True  True  True ...  True  True  True]' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   client.loc[:,col] = client[col].astype(bool)
# /var/folders/rk/vsbmyjqx09n87m8t22syxyvr0000gn/T/ipykernel_94644/1961928141.py:6: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[nan nan nan ... nan nan nan]' has dtype incompatible with bool, please explicitly cast to a compatible dtype first.
#   client.loc[:,col] = client[col].map({"yes": 1,
# /var/folders/rk/vsbmyjqx09n87m8t22syxyvr0000gn/T/ipykernel_94644/1961928141.py:9: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[ True  True  True ...  True  True  True]' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   client.loc[:,col] = client[col].astype(bool)

# %% [markdown]
# ### Campaign

# %%
# Editing the campaign dataset
# Change campaign_outcome to binary values
campaign.loc[:,"campaign_outcome"] = campaign["campaign_outcome"].map({"yes": 1, 
                                                                 "no": 0})

# %%
# Convert previous_outcome to binary values
campaign.loc[:,"previous_outcome"] = campaign["previous_outcome"].map({"success": 1, 
                                                                 "failure": 0,
                                                                 "nonexistent": 0})

# %%
# Add year column
campaign.loc[:,"year"] = "2022"

# Convert day to string
campaign.loc[:,"day"] = campaign["day"].astype(str)

# Add last_contact_date column
campaign.loc[:,"last_contact_date"] = campaign["year"] + "-" + campaign["month"] + "-" + campaign["day"]

# %%
campaign.head()
# Out:
#    client_id  number_contacts month day  contact_duration  \
# 0          0                1   may  13               261
# 1          1                1   may  19               149
# 2          2                1   may  23               226
# 3          3                1   may  27               151
# 4          4                1   may   3               307
#
#    previous_campaign_contacts previous_outcome campaign_outcome  year  \
# 0                           0                0                0  2022
# 1                           0                0                0  2022
# 2                           0                0                0  2022
# 3                           0                0                0  2022
# 4                           0                0                0  2022
#
#   last_contact_date
# 0       2022-may-13
# 1       2022-may-19
# 2       2022-may-23
# 3       2022-may-27
# 4        2022-may-3

# %%
# Convert to datetime
campaign.loc[:,"last_contact_date"] = pd.to_datetime(campaign["last_contact_date"], 
                                               format="%Y-%b-%d")

# %%
# Clean and convert outcome columns to bool
for col in ["campaign_outcome", "previous_outcome"]:
  campaign.loc[:,col] = campaign[col].astype(bool)

# %%
# Drop unneccessary columns
campaign.drop(columns=["month", "day", "year"], inplace=True)
# Out:
# /var/folders/rk/vsbmyjqx09n87m8t22syxyvr0000gn/T/ipykernel_94644/2630801147.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   campaign.drop(columns=["month", "day", "year"], inplace=True)

# %%
campaign.head()
# Out:
#    client_id  number_contacts  contact_duration  previous_campaign_contacts  \
# 0          0                1               261                           0
# 1          1                1               149                           0
# 2          2                1               226                           0
# 3          3                1               151                           0
# 4          4                1               307                           0
#
#   previous_outcome campaign_outcome    last_contact_date
# 0            False            False  2022-05-13 00:00:00
# 1            False            False  2022-05-19 00:00:00
# 2            False            False  2022-05-23 00:00:00
# 3            False            False  2022-05-27 00:00:00
# 4            False            False  2022-05-03 00:00:00

# %%
client.head()
# Out:
#    client_id  age        job  marital    education  credit_default  mortgage
# 0          0   56  housemaid  married     basic_4y            True      True
# 1          1   57   services  married  high_school            True      True
# 2          2   37   services  married  high_school            True      True
# 3          3   40     admin_  married     basic_6y            True      True
# 4          4   56   services  married  high_school            True      True

# %%
economics.head()
# Out:
#    client_id  cons_price_idx  euribor_three_months
# 0          0          93.994                 4.857
# 1          1          93.994                 4.857
# 2          2          93.994                 4.857
# 3          3          93.994                 4.857
# 4          4          93.994                 4.857

# %%
# Save tables to individual csv files
client.to_csv("client.csv", index=False)
campaign.to_csv("campaign.csv", index=False)
economics.to_csv("economics.csv", index=False)
